# %% [markdown]
# # Part 3

# %% [markdown]
# # we are monitoring daily % change on that category level and getting RS of the bucket

# %% [markdown]
# Get the daily percentage change for each coin from Part 2

# %%
# %%capture --no-display
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install pandas

# %%
import pandas as pd
all_coin_data_df = pd.read_csv("./output_files/all_coin_data.csv")
all_coin_data_df
# Out:
#        Unnamed: 0  Kline open time  Open price  High price  Low price  \
# 0               0    1667260800000      0.2546      0.2584     0.2513
# 1               1    1667347200000      0.2536      0.2627     0.2439
# 2               2    1667433600000      0.2506      0.2667     0.2496
# 3               3    1667520000000      0.2626      0.2832     0.2614
# 4               4    1667606400000      0.2812      0.2869     0.2693
# ...           ...              ...         ...         ...        ...
# 73590         175    1682380800000      0.4870      0.4960     0.4710
# 73591         176    1682467200000      0.4940      0.5100     0.4550
# 73592         177    1682553600000      0.4790      0.4960     0.4760
# 73593         178    1682640000000      0.4890      0.4910     0.4760
# 73594         179    1682726400000      0.4830      0.5030     0.4800
#
#        Close price      Volume  Kline close time  Quote asset volume  \
# 0           0.2536   2549748.0     1667347199999        6.508749e+05
# 1           0.2505  12911850.0     1667433599999        3.284319e+06
# 2           0.2626   8747303.0     1667519999999        2.285646e+06
# 3           0.2813  11131195.0     1667606399999        3.036567e+06
# 4           0.2742   8638581.0     1667692799999        2.410939e+06
# ...            ...         ...               ...                 ...
# 73590       0.4940   2336695.9     1682467199999        1.119615e+06
# 73591       0.4800   4378243.1     1682553599999        2.129181e+06
# 73592       0.4900   2693679.1     1682639999999        1.308918e+06
# 73593       0.4830   2330769.9     1682726399999        1.122949e+06
# 73594       0.5010   4478155.7     1682812799999        2.206031e+06
#
#        Number of trades  Taker buy base asset volume  \
# 0                  4628                    1270454.0
# 1                 16798                    6429016.0
# 2                 13264                    4269176.0
# 3                 18091                    5509059.0
# 4                 16571                    4262459.0
# ...                 ...                          ...
# 73590              6228                    1134999.9
# 73591             12098                    2161668.7
# 73592              8220                    1460957.3
# 73593              6167                    1100141.2
# 73594              7799                    2115103.5
#
#        Taker buy quote asset volume  Unused field. Ignore.        Coin  \
# 0                      3.244097e+05                      0    ZRX/USDT
# 1                      1.636394e+06                      0    ZRX/USDT
# 2                      1.115772e+06                      0    ZRX/USDT
# 3                      1.503802e+06                      0    ZRX/USDT
# 4                      1.189955e+06                      0    ZRX/USDT
# ...                             ...                    ...         ...
# 73590                  5.441065e+05                      0  1INCH/USDT
# 73591                  1.050130e+06                      0  1INCH/USDT
# 73592                  7.095446e+05                      0  1INCH/USDT
# 73593                  5.300439e+05                      0  1INCH/USDT
# 73594                  1.041293e+06                      0  1INCH/USDT
#
#        Daily Close price pct_change
# 0                               NaN
# 1                         -0.012224
# 2                          0.048303
# 3                          0.071211
# 4                         -0.025240
# ...                             ...
# 73590                      0.014374
# 73591                     -0.028340
# 73592                      0.020833
# 73593                     -0.014286
# 73594                      0.037267
#
# [73595 rows x 15 columns]

# %% [markdown]
# Relative Strength of a coin is the % change of coin by % change of btc

# %%
df = all_coin_data_df.loc[all_coin_data_df['Coin'] == "BTC/USDT"]
dict_d = df.set_index("Kline open time").to_dict()["Daily Close price pct_change"]

def get_relative_strength(open_time, close_price_pct_change):
    if dict_d.get(open_time): 
        return close_price_pct_change / dict_d[open_time]
    return 0

def add_relative_strength_to_df(df):
    df["relative_strength"] = df.apply(lambda row: get_relative_strength(row['Kline open time'], row['Daily Close price pct_change']), axis=1)
    return df

# %%
import glob
import os 
for category_wise_coin_data_file in glob.glob("./output_files/category_wise_*.csv"):
    file_name = category_wise_coin_data_file.split("\\")[-1]
    temp_df = pd.read_csv(category_wise_coin_data_file)
    add_relative_strength_to_df(temp_df)
    # temp_df.to_csv(os.path.join(".","",f"file_{file_name}"))
    temp_df.to_csv(f"{file_name}")

# %%
import glob
import os
for category_wise_coin_data_file in glob.glob("./output_files/category_wise_*.csv"):
    file_name = os.path.split(category_wise_coin_data_file)[-1]
    temp_df = pd.read_csv(category_wise_coin_data_file)
    add_relative_strength_to_df(temp_df)
    temp_df.to_csv(f"./output_files/final_{file_name}")

# %% [markdown]
# # We are also monitoring the RS of coins on global and bucket level

# %%
# Add relative strength to all coin (global)
add_relative_strength_to_df(all_coin_data_df)
all_coin_data_df.to_csv("./output_files/final_all_coin_data_with_relative_strength.csv")
